# %%
# %matplotlib inline
import itertools
import matplotlib.pyplot as plt
from time import time
from tqdm import tqdm
import datetime
import os
import numpy as np
import tensorflow as tf
import keras
import sklearn.model_selection as sk
import copy
from PIL import Image as IM
from keras.callbacks import TensorBoard
import cv2
import json
import pathlib
from glob import glob
from sklearn.metrics import confusion_matrix, precision_recall_curve, average_precision_score

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
## import helpers
from helpers import data_loaders as dls
from helpers import pointcloud as pc
from helpers.viz import plot, plot_history, ConfusionMatrix
from helpers.logger import Logger
import utils
## import networks
from dl_models import get_unet_model
from evaluate_model import *

# %% [markdown]
# ### Classic + Geometry

# %%
model_name = 'unet'
weights = 'output/experiment0/unet_2019_09_04_12_27/model/best_model.h5'
f_test_c_g, gt_test_c_g, model_c_g, scores_c_g, pred_c_g, times_c_g, conf_mat_c_g = evaluate_model(model_name, weights, view='front', plot_result_flag=False)
# Out:
# 100%|██████████| 229/229 [00:00<00:00, 1617.22it/s]
# 100%|██████████| 30/30 [00:00<00:00, 1547.94it/s]
# 100%|██████████| 30/30 [00:00<00:00, 1451.95it/s]
# {'name': 'experiment0', 'test_name': 'Classical_Geometric_', 'run_id': 'unet_2019_09_04_12_27', 'dataset': 'KITTI', 'training_config': {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}}
# {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}
# dict_keys(['imgs', 'calib', 'gt', 'gt_bev', 'gt_front', 'lodnn_gt', 'pc'])
# Reading cloud
# Reading calibration files
# Reading camera images
# (259, 2)
# Height ranges from -30.21500015258789 to 2.9130001068115234
# Evaluating count
# Count varies from 0 to 17
# Extracting features
# Evaluated in : 3.1209957599639893
# Test set shape (30, 64, 943, 9)
# GT set shape (30, 64, 943, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 944, 9)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 944, 8)   656         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 472, 8)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 472, 16)  1168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 236, 16)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 236, 32)  4640        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 236, 32)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 118, 32)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 118, 32)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 236, 32)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 236, 32)  4128        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 236, 64)  0           dropout_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 236, 16)  9232        concatenate_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 472, 16)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 472, 16)  1040        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 472, 32)  0           conv2d_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 472, 16)  4624        concatenate_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 944, 16)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 944, 16)  1040        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 944, 24)  0           conv2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 944, 8)   1736        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 944, 2)   146         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 944, 2)   6           conv2d_10[0][0]
# ==================================================================================================
# Total params: 28,416
# Trainable params: 28,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/leonardo/Dev/github/crispy-eureka/nbs/dl_models.py:109: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = keras.models.Model(input = inputs, output = conv10)
# Elapsed time to exectute predict_sample: 1.3072071075439453
# Elapsed time to exectute predict_sample: 0.009397506713867188
# Elapsed time to exectute predict_sample: 0.009174585342407227
# Elapsed time to exectute predict_sample: 0.009228706359863281
# Elapsed time to exectute predict_sample: 0.009187698364257812
# Elapsed time to exectute predict_sample: 0.009053468704223633
# Elapsed time to exectute predict_sample: 0.00901341438293457
# Elapsed time to exectute predict_sample: 0.009064912796020508
# Elapsed time to exectute predict_sample: 0.009001731872558594
# Elapsed time to exectute predict_sample: 0.009178876876831055
# Elapsed time to exectute predict_sample: 0.009134769439697266
# Elapsed time to exectute predict_sample: 0.009235858917236328
# Elapsed time to exectute predict_sample: 0.009210824966430664
# Elapsed time to exectute predict_sample: 0.009414434432983398
# Elapsed time to exectute predict_sample: 0.00926828384399414
# Elapsed time to exectute predict_sample: 0.009112119674682617
# Elapsed time to exectute predict_sample: 0.009058237075805664
# Elapsed time to exectute predict_sample: 0.00904536247253418
# Elapsed time to exectute predict_sample: 0.00923609733581543
# Elapsed time to exectute predict_sample: 0.009364604949951172
# Elapsed time to exectute predict_sample: 0.009175300598144531
# Elapsed time to exectute predict_sample: 0.009135007858276367
# Elapsed time to exectute predict_sample: 0.011943817138671875
# Elapsed time to exectute predict_sample: 0.009232759475708008
# Elapsed time to exectute predict_sample: 0.009311914443969727
# Elapsed time to exectute predict_sample: 0.00954747200012207
# Elapsed time to exectute predict_sample: 0.010123968124389648
# Elapsed time to exectute predict_sample: 0.009850740432739258
# Elapsed time to exectute predict_sample: 0.009261608123779297
# Elapsed time to exectute predict_sample: 0.009988069534301758
# Mean prediction time: 0.052638641993204754. Std prediction time: 0.2329681554614143
# (30, 64, 943, 2) (30, 64, 943, 2)
# Scores: F1 -> 0.900647579566646, Recall -> 0.8916200774098421, Precision -> 0.9098597553712376, Accuracy -> 0.9823154162248144, Jaccard -> 0.819252828143699
# ------------------------------------------------
# (30, 64, 943, 2)
# (30, 64, 943, 2)
# Normalized confusion matrix
# [[0.99127437 0.00872563]
#  [0.10837992 0.89162008]]
# Overall Accuracy: 0.9823154162248144
# IoU: 0.9000135871219488

# %%
print("Scores:", scores_c_g)
print("Mean prediction time: ", times_c_g[1:].mean())
# Out:
# Scores: {'f1': 0.900647579566646, 'recall': 0.8916200774098421, 'precision': 0.9098597553712376, 'acc': 0.9823154162248144, 'jaccard': 0.819252828143699}
# Mean prediction time:  0.00937766042248956

# %%
plt.style.use('classic')

# %%
n = np.random.randint(len(gt_test_c_g))
print(n)
# n = 12
f, ax = plt.subplots(4, 1, figsize=(20,7))
ax[0].imshow(gt_test_c_g[n, :, :, 0])
ax[0].set_title('Ground Truth')
ax[0].axis('off')
ax[1].imshow(pred_c_g[n, :, :, 0])
ax[1].set_title('Road class heatmap'.format(n))
ax[1].axis('off')
ax[2].imshow(pred_c_g[n, :, :, 1])
ax[2].set_title('Not-Road class heatmap'.format(n))
ax[2].axis('off')

ax[3].imshow(1 - np.argmax(pred_c_g[n, :, :, :], axis=2))
ax[3].set_title('Prediction'.format(n))
ax[3].axis('off')
# plt.tight_layout()
plt.savefig('pred_classic_geom_sub_hog.eps', dpi=90)

plt.show()
# Out:
# 11

# %% [markdown]
# ### Classic

# %%
model_name = 'unet'
weights = 'output/experiment0/unet_2019_09_04_12_16/model/best_model.h5'
f_test_c, gt_test_c, model_c, scores_c, pred_c, times_c, conf_mat_c = evaluate_model(model_name, weights, view='front', plot_result_flag=False)
# Out:
# 100%|██████████| 229/229 [00:00<00:00, 3441.48it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3678.89it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3263.54it/s]
# {'name': 'experiment0', 'test_name': 'Classical_', 'run_id': 'unet_2019_09_04_12_16', 'dataset': 'KITTI', 'training_config': {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}}
# {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}
# dict_keys(['imgs', 'calib', 'gt', 'gt_bev', 'gt_front', 'lodnn_gt', 'pc'])
# Reading cloud
# Reading calibration files
# Reading camera images
# (259, 2)
# Height ranges from -30.21500015258789 to 2.9130001068115234
# Evaluating count
# Count varies from 0 to 17
# Extracting features
# Evaluated in : 1.8860771656036377
# Test set shape (30, 64, 943, 6)
# GT set shape (30, 64, 943, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 64, 944, 6)   0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 944, 8)   440         input_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 472, 8)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 472, 16)  1168        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 64, 236, 16)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 236, 32)  4640        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 236, 32)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 118, 32)  0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 118, 32)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 64, 236, 32)  0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 236, 32)  4128        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 236, 64)  0           dropout_5[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 236, 16)  9232        concatenate_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 64, 472, 16)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 472, 16)  1040        up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64, 472, 32)  0           conv2d_24[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 472, 16)  4624        concatenate_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 64, 944, 16)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 944, 16)  1040        up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 64, 944, 24)  0           conv2d_23[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 944, 8)   1736        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 944, 2)   146         conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 944, 2)   6           conv2d_32[0][0]
# ==================================================================================================
# Total params: 28,200
# Trainable params: 28,200
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/leonardo/Dev/github/crispy-eureka/nbs/dl_models.py:109: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = keras.models.Model(input = inputs, output = conv10)
# Elapsed time to exectute predict_sample: 0.12930703163146973
# Elapsed time to exectute predict_sample: 0.010263919830322266
# Elapsed time to exectute predict_sample: 0.009996891021728516
# Elapsed time to exectute predict_sample: 0.009972333908081055
# Elapsed time to exectute predict_sample: 0.009980440139770508
# Elapsed time to exectute predict_sample: 0.01011514663696289
# Elapsed time to exectute predict_sample: 0.009975910186767578
# Elapsed time to exectute predict_sample: 0.009997844696044922
# Elapsed time to exectute predict_sample: 0.009944438934326172
# Elapsed time to exectute predict_sample: 0.010036706924438477
# Elapsed time to exectute predict_sample: 0.010008573532104492
# Elapsed time to exectute predict_sample: 0.010039567947387695
# Elapsed time to exectute predict_sample: 0.010042190551757812
# Elapsed time to exectute predict_sample: 0.010062932968139648
# Elapsed time to exectute predict_sample: 0.010026216506958008
# Elapsed time to exectute predict_sample: 0.0101165771484375
# Elapsed time to exectute predict_sample: 0.010163545608520508
# Elapsed time to exectute predict_sample: 0.010024309158325195
# Elapsed time to exectute predict_sample: 0.01008152961730957
# Elapsed time to exectute predict_sample: 0.009975671768188477
# Elapsed time to exectute predict_sample: 0.009890079498291016
# Elapsed time to exectute predict_sample: 0.009369373321533203
# Elapsed time to exectute predict_sample: 0.009176492691040039
# Elapsed time to exectute predict_sample: 0.009511232376098633
# Elapsed time to exectute predict_sample: 0.009953975677490234
# Elapsed time to exectute predict_sample: 0.010254383087158203
# Elapsed time to exectute predict_sample: 0.01009058952331543
# Elapsed time to exectute predict_sample: 0.009114503860473633
# Elapsed time to exectute predict_sample: 0.009068965911865234
# Elapsed time to exectute predict_sample: 0.009076595306396484
# Mean prediction time: 0.013854598999023438. Std prediction time: 0.02144176655298474
# (30, 64, 943, 2) (30, 64, 943, 2)
# Scores: F1 -> 0.8480522650918941, Recall -> 0.8963813970633409, Precision -> 0.8046679388049989, Accuracy -> 0.9711227465535525, Jaccard -> 0.7361898803156599
# ------------------------------------------------
# (30, 64, 943, 2)
# (30, 64, 943, 2)
# Normalized confusion matrix
# [[0.97850576 0.02149424]
#  [0.1036186  0.8963814 ]]
# Overall Accuracy: 0.9711227465535525
# IoU: 0.8523907946767215

# %%
print("Scores:", scores_c)
print("Mean prediction time: ", times_c[1:].mean())
# Out:
# Scores: {'f1': 0.8480522650918941, 'recall': 0.8963813970633409, 'precision': 0.8046679388049989, 'acc': 0.9711227465535525, 'jaccard': 0.7361898803156599}
# Mean prediction time:  0.009657021226554081

# %%
n = np.random.randint(len(gt_test_c))
print(n)
# n = 12
f, ax = plt.subplots(4, 1, figsize=(20,7))
ax[0].imshow(gt_test_c[n, :, :, 0])
ax[0].set_title('Ground Truth')
ax[0].axis('off')
ax[1].imshow(pred_c[n, :, :, 0])
ax[1].set_title('Road class heatmap'.format(n))
ax[1].axis('off')
ax[2].imshow(pred_c[n, :, :, 1])
ax[2].set_title('Not-Road class heatmap'.format(n))
ax[2].axis('off')

ax[3].imshow(1 - np.argmax(pred_c[n, :, :, :], axis=2))
ax[3].set_title('Prediction'.format(n))
ax[3].axis('off')
# plt.tight_layout()
plt.savefig('pred_classic_geom_sub_hog.eps', dpi=90)

plt.show()
# Out:
# 25

# %% [markdown]
# ### Classic + Geometric + Subsampled 32

# %%
model_name = 'unet'
weights = 'output/experiment0/unet_2019_09_04_15_26/model/best_model.h5'
f_test_c_g_s_32, gt_test_c_g_s_32, model_c_g_s_32, scores_c_g_s_32, pred_c_g_s_32, times_c_g_s_32, conf_mat_c_g_s_32 = evaluate_model(model_name, weights, view='front', plot_result_flag=False)
# Out:
# 100%|██████████| 229/229 [00:00<00:00, 3536.43it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3299.31it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3249.72it/s]
# {'name': 'experiment0', 'test_name': 'Classical_Geometric_Subsampled_32', 'run_id': 'unet_2019_09_04_15_26', 'dataset': 'KITTI', 'training_config': {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}}
# {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}
# dict_keys(['imgs', 'calib', 'gt', 'gt_bev', 'gt_front', 'lodnn_gt', 'pc'])
# Reading cloud
# Reading calibration files
# Reading camera images
# (259, 2)
# Height ranges from -30.21500015258789 to 2.9130001068115234
# Read and Subsample cloud
# Evaluated in : 0.8330681324005127
# Evaluating count
# Count varies from 0 to 10
# Extracting features
# Evaluated in : 1.362985610961914
# Test set shape (30, 32, 943, 9)
# GT set shape (30, 64, 943, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 32, 944, 9)   0
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 944, 8)   656         input_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 32, 472, 8)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 472, 16)  1168        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 32, 236, 16)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 236, 32)  4640        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 236, 32)  0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 32, 118, 32)  0           dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 118, 32)  0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 32, 236, 32)  0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 236, 32)  4128        up_sampling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 236, 64)  0           dropout_11[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 236, 16)  9232        concatenate_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 32, 472, 16)  0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 472, 16)  1040        up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 32, 472, 32)  0           conv2d_59[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 472, 16)  4624        concatenate_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 32, 944, 16)  0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 944, 16)  1040        up_sampling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 32, 944, 24)  0           conv2d_58[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 944, 8)   1736        concatenate_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 64, 944, 8)   0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 64, 944, 8)   584         up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 64, 944, 2)   146         conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 944, 2)   6           conv2d_68[0][0]
# ==================================================================================================
# Total params: 29,000
# Trainable params: 29,000
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Elapsed time to exectute predict_sample: 0.1486036777496338
# Elapsed time to exectute predict_sample: 0.007363080978393555
# Elapsed time to exectute predict_sample: 0.007256507873535156
# Elapsed time to exectute predict_sample: 0.007214069366455078
# Elapsed time to exectute predict_sample: 0.007220268249511719
# Elapsed time to exectute predict_sample: 0.00733637809753418
# Elapsed time to exectute predict_sample: 0.007237911224365234
# Elapsed time to exectute predict_sample: 0.007317781448364258
# Elapsed time to exectute predict_sample: 0.007337093353271484
# Elapsed time to exectute predict_sample: 0.007294654846191406
# Elapsed time to exectute predict_sample: 0.007318973541259766
# Elapsed time to exectute predict_sample: 0.007301807403564453
# Elapsed time to exectute predict_sample: 0.007528066635131836
# Elapsed time to exectute predict_sample: 0.007390737533569336
# Elapsed time to exectute predict_sample: 0.0072629451751708984
# Elapsed time to exectute predict_sample: 0.00738215446472168
# Elapsed time to exectute predict_sample: 0.007496356964111328
# Elapsed time to exectute predict_sample: 0.0075571537017822266
# Elapsed time to exectute predict_sample: 0.007342815399169922
# Elapsed time to exectute predict_sample: 0.007672309875488281
# Elapsed time to exectute predict_sample: 0.008106231689453125
# Elapsed time to exectute predict_sample: 0.008759737014770508
# Elapsed time to exectute predict_sample: 0.008051872253417969
# Elapsed time to exectute predict_sample: 0.008443593978881836
# Elapsed time to exectute predict_sample: 0.007980823516845703
# Elapsed time to exectute predict_sample: 0.008690118789672852
# Elapsed time to exectute predict_sample: 0.008100271224975586
# Elapsed time to exectute predict_sample: 0.008581399917602539
# Elapsed time to exectute predict_sample: 0.008190631866455078
# Elapsed time to exectute predict_sample: 0.008082389831542969
# Mean prediction time: 0.012380727132161458. Std prediction time: 0.025300457022590185
# (30, 64, 943, 2) (30, 64, 943, 2)
# Scores: F1 -> 0.9112337712819715, Recall -> 0.9001351600417767, Precision -> 0.9226094896256415, Accuracy -> 0.9842341595970308, Jaccard -> 0.8369416200159945
# ------------------------------------------------
# (30, 64, 943, 2)
# (30, 64, 943, 2)
# Normalized confusion matrix
# [[0.99254153 0.00745847]
#  [0.09986484 0.90013516]]
# Overall Accuracy: 0.9842341595970308
# IoU: 0.9098938184001981

# %%
print("Scores:", scores_c_g_s_32)
print("Mean prediction time: ", times_c_g_s_32[1:].mean())
# Out:
# Scores: {'f1': 0.9112337712819715, 'recall': 0.9001351600417767, 'precision': 0.9226094896256415, 'acc': 0.9842341595970308, 'jaccard': 0.8369416200159945}
# Mean prediction time:  0.007683384007421033

# %%
n = np.random.randint(len(gt_test_c))
print(n)
# n = 12
f, ax = plt.subplots(4, 1, figsize=(20,7))
ax[0].imshow(gt_test_c_g_s_32[n, :, :, 0])
ax[0].set_title('Ground Truth')
ax[0].axis('off')
ax[1].imshow(pred_c_g_s_32[n, :, :, 0])
ax[1].set_title('Road class heatmap'.format(n))
ax[1].axis('off')
ax[2].imshow(pred_c_g_s_32[n, :, :, 1])
ax[2].set_title('Not-Road class heatmap'.format(n))
ax[2].axis('off')

ax[3].imshow(1 - np.argmax(pred_c_g_s_32[n, :, :, :], axis=2))
ax[3].set_title('Prediction'.format(n))
ax[3].axis('off')
# plt.tight_layout()
plt.savefig('pred_classic_geom_sub_hog.eps', dpi=90)

plt.show()
# Out:
# 24

# %% [markdown]
# ### Classic + Subsampled 32

# %%
model_name = 'unet'
weights = 'output/experiment0/unet_2019_09_04_15_57/model/best_model.h5'
f_test_c_s_32, gt_test_c_s_32, model_c_s_32, scores_c_s_32, pred_c_s_32, times_c_s_32, conf_mat_c_s_32 = evaluate_model(model_name, weights, view='front', plot_result_flag=False)
# Out:
# 100%|██████████| 229/229 [00:00<00:00, 3752.76it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3398.77it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3496.90it/s]
# {'name': 'experiment0', 'test_name': 'Classical_Subsampled_32', 'run_id': 'unet_2019_09_04_15_57', 'dataset': 'KITTI', 'training_config': {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}}
# {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}
# dict_keys(['imgs', 'calib', 'gt', 'gt_bev', 'gt_front', 'lodnn_gt', 'pc'])
# Reading cloud
# Reading calibration files
# Reading camera images
# (259, 2)
# Height ranges from -30.21500015258789 to 2.9130001068115234
# Read and Subsample cloud
# Evaluated in : 0.8589541912078857
# Evaluating count
# Count varies from 0 to 10
# Extracting features
# Evaluated in : 1.7034094333648682
# Test set shape (30, 32, 943, 6)
# GT set shape (30, 64, 943, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 32, 944, 6)   0
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 944, 8)   440         input_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 32, 472, 8)   0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 472, 16)  1168        max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 32, 236, 16)  0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 236, 32)  4640        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 236, 32)  0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 32, 118, 32)  0           dropout_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 118, 32)  0           max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 32, 236, 32)  0           dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 236, 32)  4128        up_sampling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 32, 236, 64)  0           dropout_13[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 236, 16)  9232        concatenate_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 32, 472, 16)  0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 472, 16)  1040        up_sampling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 32, 472, 32)  0           conv2d_71[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 472, 16)  4624        concatenate_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_24 (UpSampling2D) (None, 32, 944, 16)  0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 944, 16)  1040        up_sampling2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 944, 24)  0           conv2d_70[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 944, 8)   1736        concatenate_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_25 (UpSampling2D) (None, 64, 944, 8)   0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 944, 8)   584         up_sampling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 944, 2)   146         conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 64, 944, 2)   6           conv2d_80[0][0]
# ==================================================================================================
# Total params: 28,784
# Trainable params: 28,784
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /home/leonardo/Dev/github/crispy-eureka/nbs/dl_models.py:109: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = keras.models.Model(input = inputs, output = conv10)
# Elapsed time to exectute predict_sample: 0.1946413516998291
# Elapsed time to exectute predict_sample: 0.007360219955444336
# Elapsed time to exectute predict_sample: 0.007120370864868164
# Elapsed time to exectute predict_sample: 0.008690595626831055
# Elapsed time to exectute predict_sample: 0.007005929946899414
# Elapsed time to exectute predict_sample: 0.007026195526123047
# Elapsed time to exectute predict_sample: 0.0070037841796875
# Elapsed time to exectute predict_sample: 0.0070574283599853516
# Elapsed time to exectute predict_sample: 0.0070171356201171875
# Elapsed time to exectute predict_sample: 0.006975650787353516
# Elapsed time to exectute predict_sample: 0.006891965866088867
# Elapsed time to exectute predict_sample: 0.006954193115234375
# Elapsed time to exectute predict_sample: 0.00695490837097168
# Elapsed time to exectute predict_sample: 0.007014751434326172
# Elapsed time to exectute predict_sample: 0.006934642791748047
# Elapsed time to exectute predict_sample: 0.006943941116333008
# Elapsed time to exectute predict_sample: 0.006989002227783203
# Elapsed time to exectute predict_sample: 0.006937503814697266
# Elapsed time to exectute predict_sample: 0.006890058517456055
# Elapsed time to exectute predict_sample: 0.006900787353515625
# Elapsed time to exectute predict_sample: 0.0068204402923583984
# Elapsed time to exectute predict_sample: 0.0069997310638427734
# Elapsed time to exectute predict_sample: 0.0070040225982666016
# Elapsed time to exectute predict_sample: 0.007099628448486328
# Elapsed time to exectute predict_sample: 0.00717926025390625
# Elapsed time to exectute predict_sample: 0.007161855697631836
# Elapsed time to exectute predict_sample: 0.007608890533447266
# Elapsed time to exectute predict_sample: 0.00820302963256836
# Elapsed time to exectute predict_sample: 0.006993770599365234
# Elapsed time to exectute predict_sample: 0.008044958114624023
# Mean prediction time: 0.013414200146993. Std prediction time: 0.03365565091457639
# (30, 64, 943, 2) (30, 64, 943, 2)
# Scores: F1 -> 0.8766687818431608, Recall -> 0.8742397247650059, Precision -> 0.8791113747003731, Accuracy -> 0.9778863997879109, Jaccard -> 0.78041878270026
# ------------------------------------------------
# (30, 64, 943, 2)
# (30, 64, 943, 2)
# Normalized confusion matrix
# [[0.9881247  0.0118753 ]
#  [0.12576028 0.87423972]]
# Overall Accuracy: 0.9778863997879109
# IoU: 0.8782094632813637

# %%
print("Scores:", scores_c_s_32)
print("Mean prediction time: ", times_c_s_32[1:].mean())
# Out:
# Scores: {'f1': 0.8766687818431608, 'recall': 0.8742397247650059, 'precision': 0.8791113747003731, 'acc': 0.9778863997879109, 'jaccard': 0.78041878270026}
# Mean prediction time:  0.007164988024481411

# %%
n = np.random.randint(len(gt_test_c))
print(n)
# n = 12
f, ax = plt.subplots(4, 1, figsize=(20,7))
ax[0].imshow(gt_test_c_s_32[n, :, :, 0])
ax[0].set_title('Ground Truth')
ax[0].axis('off')
ax[1].imshow(pred_c_s_32[n, :, :, 0])
ax[1].set_title('Road class heatmap'.format(n))
ax[1].axis('off')
ax[2].imshow(pred_c_s_32[n, :, :, 1])
ax[2].set_title('Not-Road class heatmap'.format(n))
ax[2].axis('off')

ax[3].imshow(1 - np.argmax(pred_c_s_32[n, :, :, :], axis=2))
ax[3].set_title('Prediction'.format(n))
ax[3].axis('off')
# plt.tight_layout()
plt.savefig('pred_classic_geom_sub_hog.eps', dpi=90)

plt.show()
# Out:
# 21

# %% [markdown]
# ### Classic + Geometric + Subsampled 16

# %%
model_name = 'unet'
weights = 'output/experiment0/unet_2019_09_04_15_22/model/best_model.h5'
f_test_c_g_s_16, gt_test_c_g_s_16, model_c_g_s_16, scores_c_g_s_16, pred_c_g_s_16, times_c_g_s_16, conf_mat_c_g_s_16 = evaluate_model(model_name, weights, view='front', plot_result_flag=False)
# Out:
# 100%|██████████| 229/229 [00:00<00:00, 3579.92it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3451.63it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3348.30it/s]
# {'name': 'experiment0', 'test_name': 'Classical_Geometric_Subsampled_16', 'run_id': 'unet_2019_09_04_15_22', 'dataset': 'KITTI', 'training_config': {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}}
# {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}
# dict_keys(['imgs', 'calib', 'gt', 'gt_bev', 'gt_front', 'lodnn_gt', 'pc'])
# Reading cloud
# Reading calibration files
# Reading camera images
# (259, 2)
# Height ranges from -30.21500015258789 to 2.9130001068115234
# Read and Subsample cloud
# Evaluated in : 0.8061580657958984
# Evaluating count
# Count varies from 0 to 6
# Extracting features
# Evaluated in : 1.0686793327331543
# Test set shape (30, 16, 943, 9)
# GT set shape (30, 64, 943, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 16, 944, 9)   0
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 16, 944, 8)   656         input_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 16, 472, 8)   0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 472, 16)  1168        max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 16, 236, 16)  0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 236, 32)  4640        max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 16, 236, 32)  0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 16, 118, 32)  0           dropout_19[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 16, 118, 32)  0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_36 (UpSampling2D) (None, 16, 236, 32)  0           dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 16, 236, 32)  4128        up_sampling2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 16, 236, 64)  0           dropout_19[0][0]
#                                                                  conv2d_111[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 16, 236, 16)  9232        concatenate_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 16, 472, 16)  0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 472, 16)  1040        up_sampling2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 16, 472, 32)  0           conv2d_109[0][0]
#                                                                  conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 472, 16)  4624        concatenate_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 16, 944, 16)  0           conv2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 944, 16)  1040        up_sampling2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 16, 944, 24)  0           conv2d_108[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 944, 8)   1736        concatenate_30[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_39 (UpSampling2D) (None, 32, 944, 8)   0           conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 32, 944, 8)   584         up_sampling2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_40 (UpSampling2D) (None, 64, 944, 8)   0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 64, 944, 8)   584         up_sampling2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 64, 944, 2)   146         conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 64, 944, 2)   6           conv2d_119[0][0]
# ==================================================================================================
# Total params: 29,584
# Trainable params: 29,584
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Elapsed time to exectute predict_sample: 0.246567964553833
# Elapsed time to exectute predict_sample: 0.006100893020629883
# Elapsed time to exectute predict_sample: 0.005990028381347656
# Elapsed time to exectute predict_sample: 0.005888938903808594
# Elapsed time to exectute predict_sample: 0.0062334537506103516
# Elapsed time to exectute predict_sample: 0.0058667659759521484
# Elapsed time to exectute predict_sample: 0.00588679313659668
# Elapsed time to exectute predict_sample: 0.005688905715942383
# Elapsed time to exectute predict_sample: 0.006088972091674805
# Elapsed time to exectute predict_sample: 0.00621485710144043
# Elapsed time to exectute predict_sample: 0.005947113037109375
# Elapsed time to exectute predict_sample: 0.006422758102416992
# Elapsed time to exectute predict_sample: 0.006922245025634766
# Elapsed time to exectute predict_sample: 0.006781339645385742
# Elapsed time to exectute predict_sample: 0.0063092708587646484
# Elapsed time to exectute predict_sample: 0.0067081451416015625
# Elapsed time to exectute predict_sample: 0.006467103958129883
# Elapsed time to exectute predict_sample: 0.005846977233886719
# Elapsed time to exectute predict_sample: 0.008115530014038086
# Elapsed time to exectute predict_sample: 0.006267070770263672
# Elapsed time to exectute predict_sample: 0.006821393966674805
# Elapsed time to exectute predict_sample: 0.0062792301177978516
# Elapsed time to exectute predict_sample: 0.007314920425415039
# Elapsed time to exectute predict_sample: 0.006226778030395508
# Elapsed time to exectute predict_sample: 0.006285667419433594
# Elapsed time to exectute predict_sample: 0.006745815277099609
# Elapsed time to exectute predict_sample: 0.0064067840576171875
# Elapsed time to exectute predict_sample: 0.007441520690917969
# Elapsed time to exectute predict_sample: 0.0061779022216796875
# Elapsed time to exectute predict_sample: 0.006331443786621094
# Mean prediction time: 0.014411552747090658. Std prediction time: 0.04311347874765392
# (30, 64, 943, 2) (30, 64, 943, 2)
# Scores: F1 -> 0.878582398256174, Recall -> 0.8716409657799349, Precision -> 0.8856352763455224, Accuracy -> 0.9783415075998586, Jaccard -> 0.7834569360155944
# ------------------------------------------------
# (30, 64, 943, 2)
# (30, 64, 943, 2)
# Normalized confusion matrix
# [[0.98888147 0.01111853]
#  [0.12835903 0.87164097]]
# Overall Accuracy: 0.9783415075998586
# IoU: 0.8799784831394909

# %%
print("Scores:", scores_c_g_s_16)
print("Mean prediction time: ", times_c_g_s_16[1:].mean())
# Out:
# Scores: {'f1': 0.878582398256174, 'recall': 0.8716409657799349, 'precision': 0.8856352763455224, 'acc': 0.9783415075998586, 'jaccard': 0.7834569360155944}
# Mean prediction time:  0.006406159236513335

# %%
n = np.random.randint(len(gt_test_c))
print(n)
# n = 12
f, ax = plt.subplots(4, 1, figsize=(20,7))
ax[0].imshow(gt_test_c_g_s_16[n, :, :, 0])
ax[0].set_title('Ground Truth')
ax[0].axis('off')
ax[1].imshow(pred_c_g_s_16[n, :, :, 0])
ax[1].set_title('Road class heatmap'.format(n))
ax[1].axis('off')
ax[2].imshow(pred_c_g_s_16[n, :, :, 1])
ax[2].set_title('Not-Road class heatmap'.format(n))
ax[2].axis('off')

ax[3].imshow(1 - np.argmax(pred_c_g_s_16[n, :, :, :], axis=2))
ax[3].set_title('Prediction'.format(n))
ax[3].axis('off')
# plt.tight_layout()
plt.savefig('pred_classic_geom_sub_hog.eps', dpi=90)

plt.show()
# Out:
# 0

# %% [markdown]
# ### Classic + Subsample 16

# %%
model_name = 'unet'
weights = 'output/experiment0/unet_2019_09_04_15_50/model/best_model.h5'
f_test_c_s_16, gt_test_c_s_16, model_c_s_16, scores_c_s_16, pred_c_s_16, times_c_s_16, conf_mat_c_s_16 = evaluate_model(model_name, weights, view='front', plot_result_flag=False)
# Out:
# 100%|██████████| 229/229 [00:00<00:00, 3283.04it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3055.59it/s]
# 100%|██████████| 30/30 [00:00<00:00, 3328.46it/s]
# {'name': 'experiment0', 'test_name': 'Classical_Subsampled_16', 'run_id': 'unet_2019_09_04_15_50', 'dataset': 'KITTI', 'training_config': {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}}
# {'loss_function': 'binary_crossentropy', 'learning_rate': 0.001, 'batch_size': 3, 'epochs': 120, 'optimizer': 'keras.optimizers.Adam'}
# dict_keys(['imgs', 'calib', 'gt', 'gt_bev', 'gt_front', 'lodnn_gt', 'pc'])
# Reading cloud
# Reading calibration files
# Reading camera images
# (259, 2)
# Height ranges from -30.21500015258789 to 2.9130001068115234
# Read and Subsample cloud
# Evaluated in : 0.8248066902160645
# Evaluating count
# Count varies from 0 to 6
# Extracting features
# Evaluated in : 1.1857080459594727
# Test set shape (30, 16, 943, 6)
# GT set shape (30, 64, 943, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           (None, 16, 944, 6)   0
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 16, 944, 8)   440         input_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 16, 472, 8)   0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 16, 472, 16)  1168        max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 16, 236, 16)  0           conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 16, 236, 32)  4640        max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 16, 236, 32)  0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 16, 118, 32)  0           dropout_21[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 16, 118, 32)  0           max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_41 (UpSampling2D) (None, 16, 236, 32)  0           dropout_22[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 16, 236, 32)  4128        up_sampling2d_41[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 16, 236, 64)  0           dropout_21[0][0]
#                                                                  conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 236, 16)  9232        concatenate_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_42 (UpSampling2D) (None, 16, 472, 16)  0           conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 16, 472, 16)  1040        up_sampling2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 16, 472, 32)  0           conv2d_122[0][0]
#                                                                  conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 16, 472, 16)  4624        concatenate_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_43 (UpSampling2D) (None, 16, 944, 16)  0           conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 16, 944, 16)  1040        up_sampling2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 16, 944, 24)  0           conv2d_121[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 16, 944, 8)   1736        concatenate_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_44 (UpSampling2D) (None, 32, 944, 8)   0           conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 32, 944, 8)   584         up_sampling2d_44[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_45 (UpSampling2D) (None, 64, 944, 8)   0           conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 64, 944, 8)   584         up_sampling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 64, 944, 2)   146         conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 64, 944, 2)   6           conv2d_132[0][0]
# ==================================================================================================
# Total params: 29,368
# Trainable params: 29,368
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Elapsed time to exectute predict_sample: 0.2808365821838379
# Elapsed time to exectute predict_sample: 0.005979061126708984
# Elapsed time to exectute predict_sample: 0.00597381591796875
# Elapsed time to exectute predict_sample: 0.005995273590087891
# Elapsed time to exectute predict_sample: 0.0060880184173583984
# Elapsed time to exectute predict_sample: 0.0059473514556884766
# Elapsed time to exectute predict_sample: 0.005806446075439453
# Elapsed time to exectute predict_sample: 0.00586247444152832
# Elapsed time to exectute predict_sample: 0.005944490432739258
# Elapsed time to exectute predict_sample: 0.006021976470947266
# Elapsed time to exectute predict_sample: 0.005890607833862305
# Elapsed time to exectute predict_sample: 0.005869150161743164
# Elapsed time to exectute predict_sample: 0.005969524383544922
# Elapsed time to exectute predict_sample: 0.0058460235595703125
# Elapsed time to exectute predict_sample: 0.005837440490722656
# Elapsed time to exectute predict_sample: 0.0059795379638671875
# Elapsed time to exectute predict_sample: 0.006079196929931641
# Elapsed time to exectute predict_sample: 0.006152629852294922
# Elapsed time to exectute predict_sample: 0.006059408187866211
# Elapsed time to exectute predict_sample: 0.005925416946411133
# Elapsed time to exectute predict_sample: 0.0057659149169921875
# Elapsed time to exectute predict_sample: 0.005988121032714844
# Elapsed time to exectute predict_sample: 0.006047725677490234
# Elapsed time to exectute predict_sample: 0.0058689117431640625
# Elapsed time to exectute predict_sample: 0.0057260990142822266
# Elapsed time to exectute predict_sample: 0.005841970443725586
# Elapsed time to exectute predict_sample: 0.005864143371582031
# Elapsed time to exectute predict_sample: 0.005829572677612305
# Elapsed time to exectute predict_sample: 0.005959749221801758
# Elapsed time to exectute predict_sample: 0.005760908126831055
# Mean prediction time: 0.015090584754943848. Std prediction time: 0.049347899816376904
# (30, 64, 943, 2) (30, 64, 943, 2)
# Scores: F1 -> 0.8513529321225182, Recall -> 0.8495484425877005, Precision -> 0.8531651036525173, Accuracy -> 0.9733297985153765, Jaccard -> 0.7411788667999507
# ------------------------------------------------
# (30, 64, 943, 2)
# (30, 64, 943, 2)
# Normalized confusion matrix
# [[0.98555702 0.01444298]
#  [0.15045156 0.84954844]]
# Overall Accuracy: 0.9733297985153765
# IoU: 0.8561516511877967

# %%
print("Scores:", scores_c_s_16)
print("Mean prediction time: ", times_c_s_16[1:].mean())
# Out:
# Scores: {'f1': 0.8513529321225182, 'recall': 0.8495484425877005, 'precision': 0.8531651036525173, 'acc': 0.9733297985153765, 'jaccard': 0.7411788667999507}
# Mean prediction time:  0.005926929671188881

# %%
n = np.random.randint(len(gt_test_c))
print(n)
# n = 12
f, ax = plt.subplots(4, 1, figsize=(20,7))
ax[0].imshow(gt_test_c_s_16[n, :, :, 0])
ax[0].set_title('Ground Truth')
ax[0].axis('off')
ax[1].imshow(pred_c_s_16[n, :, :, 0])
ax[1].set_title('Road class heatmap'.format(n))
ax[1].axis('off')
ax[2].imshow(pred_c_s_16[n, :, :, 1])
ax[2].set_title('Not-Road class heatmap'.format(n))
ax[2].axis('off')

ax[3].imshow(1 - np.argmax(pred_c_s_16[n, :, :, :], axis=2))
ax[3].set_title('Prediction'.format(n))
ax[3].axis('off')
# plt.tight_layout()
plt.savefig('pred_classic_geom_sub_hog.eps', dpi=90)

plt.show()
# Out:
# 23

# %% [markdown]
# ### ROC Curves

# %%
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 18})

# %%
gt_c_g     = gt_test_c_g[:,:,:,0].flatten()
p_c_g      = pred_c_g[:,:,:,0].flatten()
prec_c_g, rec_c_g, _ = precision_recall_curve(gt_c_g, p_c_g)

gt_c     = gt_test_c[:,:,:,0].flatten()
p_c      = pred_c[:,:,:,0].flatten()
prec_c, rec_c, _ = precision_recall_curve(gt_c, p_c)

gt_c_g_s_32     = gt_test_c_g_s_32[:,:,:,0].flatten()
p_c_g_s_32      = pred_c_g_s_32[:,:,:,0].flatten()
prec_c_g_s_32, rec_c_g_s_32, _ = precision_recall_curve(gt_c_g_s_32, p_c_g_s_32)

gt_c_s_32     = gt_test_c_s_32[:,:,:,0].flatten()
p_c_s_32      = pred_c_s_32[:,:,:,0].flatten()
prec_c_s_32, rec_c_s_32, _ = precision_recall_curve(gt_c_s_32, p_c_s_32)

gt_c_g_s_16     = gt_test_c_g_s_16[:,:,:,0].flatten()
p_c_g_s_16      = pred_c_g_s_16[:,:,:,0].flatten()
prec_c_g_s_16, rec_c_g_s_16, _ = precision_recall_curve(gt_c_g_s_16, p_c_g_s_16)

gt_c_s_16     = gt_test_c_s_16[:,:,:,0].flatten()
p_c_s_16      = pred_c_s_16[:,:,:,0].flatten()
prec_c_s_16, rec_c_s_16, _ = precision_recall_curve(gt_c_s_16, p_c_s_16)

# %%
# In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
plt.figure(figsize=(12,12))

plt.step(rec_c, prec_c, linewidth=2, color='xkcd:purple', alpha=0.8, where='post')
plt.step(rec_c_g, prec_c_g, linewidth=2, color='xkcd:green', alpha=0.8, where='post')

plt.step(rec_c_s_32, prec_c_s_32, linewidth=2, color='xkcd:blue', alpha=0.8, where='post')
plt.step(rec_c_g_s_32, prec_c_g_s_32, linewidth=2, color='xkcd:brown', alpha=0.8, where='post')

plt.step(rec_c_s_16, prec_c_s_16, linewidth=2, color='xkcd:red', alpha=0.8, where='post')
plt.step(rec_c_g_s_16, prec_c_g_s_16, linewidth=2, color='xkcd:teal', alpha=0.8, where='post')
# plt.step(rec_c_g_s, prec_c_g_s, linewidth=2, color='xkcd:orange', alpha=0.8, where='post')
# plt.step(rec_c_g_s_h, prec_c_g_s_h, linewidth=2, color='xkcd:goldenrod', alpha=0.8, where='post')


plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.5, 1.0])
plt.xlim([0.5, 1.0])
plt.title('Precision-Recall curve')
# plt.legend(['Classic', 'Classic + Geometrical'], loc=3)
plt.legend(['Classic',
            'Classic + Geometrical',
            'Classic + Subsampling 32',
            'Classic + Geometrical + Subsampling 32',
            'Classic + Subsampling 16',
            'Classic + Geometrical + Subsampling 16'], loc=3)
