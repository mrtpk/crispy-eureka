# %%
import data_loaders as dls
from glob import glob

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
PATH = '../../'

# %%
img_paths = glob(PATH + '/dataset/KITTI/dataset/data_road/training/image_2/*.png')[0:10]

# %%
plt.imshow(dls.get_image(img_paths[0], rgb=True, is_color=False), cmap='gray')

# %%
dls.process_kitti_pc(PATH, lambda x: x.shape, is_training=False)[0]
# Out:
# (116979, 4)

# %%
img = dls.process_kitti_img(PATH, func=lambda x: x, is_training=True, gt='kitti')[0]
plt.imshow(img)

# %%
# sorted(glob(PATH + '/dataset/KITTI/dataset/data_road_velodyne/testing/velodyne/*.bin'))
# sorted(glob(PATH + '/dataset/KITTI/dataset/data_road/testing/image_2/*.png'))
# sorted(glob(PATH + '/dataset/KITTI/dataset/data_road_velodyne/training/velodyne/*.bin'))
# sorted(glob(PATH + '/dataset/KITTI/dataset/data_road/training/image_2/*.png'))
# sorted(glob(PATH + '/dataset/LoDNN/dataset/gt/*.png'))
# sorted(glob(PATH + '/dataset/KITTI/dataset/data_road/training/gt_bev/*.png'))
